# %%
import pandas as pd
from sodapy import Socrata

# %%
client = Socrata("data.ct.gov", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results = client.get("5mzw-sjtu", limit=10000000)

# %%
df = pd.DataFrame.from_records(results)

# %%
df.head()
# Out:
#   serialnumber listyear             daterecorded           town  \
# 0       191002     2019  2019-10-01T00:00:00.000      Killingly
# 1       190009     2019  2019-10-01T00:00:00.000        Meriden
# 2       190001     2019  2019-10-01T00:00:00.000         Groton
# 3       190001     2019  2019-10-01T00:00:00.000  South Windsor
# 4       190006     2019  2019-10-01T00:00:00.000      New Haven
#
#                address assessedvalue saleamount salesratio   propertytype  \
# 0  128 SNAKE MEADOW RD        135030     176000     0.7672  Single Family
# 1         8 KENNEDY DR        201040     289000     0.6956  Single Family
# 2  117 HEATHER GLEN LN        176680     265000     0.6667  Single Family
# 3       47 HILLSIDE DR        146000     243000     0.6008  Single Family
# 4             OGDEN ST        203070     138750     1.4636            NaN
#
#   residentialtype                                    geo_coordinates  \
# 0   Single Family  {'type': 'Point', 'coordinates': [-71.83583, 4...
# 1   Single Family  {'type': 'Point', 'coordinates': [-72.787551, ...
# 2   Single Family                                                NaN
# 3   Single Family                                                NaN
# 4             NaN                                                NaN
#
#   :@computed_region_dam5_q64j :@computed_region_nhmp_cq6b  \
# 0                          39                          71
# 1                        1044                         199
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   :@computed_region_m4y2_whse :@computed_region_snd5_k6zv          nonusecode  \
# 0                          69                           5                 NaN
# 1                          80                           7                 NaN
# 2                         NaN                         NaN                 NaN
# 3                         NaN                         NaN                 NaN
# 4                         NaN                         NaN  08 - Part Interest
#
#   remarks opm_remarks
# 0     NaN         NaN
# 1     NaN         NaN
# 2     NaN         NaN
# 3     NaN         NaN
# 4     NaN         NaN

# %%
# returns 10 towns that have the highest sales ratio 
# and 10 towns that have the highest volume of sales 
# for each year available in the dataset.

# %%
print(type(df["daterecorded"].unique()[0]))
# Out:
# <class 'numpy.datetime64'>

# %%
df['daterecorded'] = df['daterecorded'].astype('datetime64[ns]')

# %%
f_dt = df["daterecorded"].unique()[0]
print(f_dt)
# Out:
# 2019-10-01T00:00:00.000000000

# %%
df = df.groupby(df['daterecorded'].map(lambda x: x.year))

# %%
df.head()
# Out:
#        serialnumber listyear daterecorded           town              address  \
# 0            191002     2019   2019-10-01      Killingly  128 SNAKE MEADOW RD
# 1            190009     2019   2019-10-01        Meriden         8 KENNEDY DR
# 2            190001     2019   2019-10-01         Groton  117 HEATHER GLEN LN
# 3            190001     2019   2019-10-01  South Windsor       47 HILLSIDE DR
# 4            190006     2019   2019-10-01      New Haven             OGDEN ST
# ...             ...      ...          ...            ...                  ...
# 811355        20003     2002   2002-10-01  East Hartford       4-6 BIGELOW ST
# 811356        20004     2002   2002-10-01  West Hartford          9 RIGGS AVE
# 811357        20005     2002   2002-10-01     Bridgeport     103 HILLCREST RD
# 811358        20002     2002   2002-10-01        Norwich     182 WIGHTMAN AVE
# 811359        20011     2002   2002-10-01       Hartford    172 1/2 BONNER ST
#
#        assessedvalue saleamount   salesratio   propertytype residentialtype  \
# 0             135030     176000       0.7672  Single Family   Single Family
# 1             201040     289000       0.6956  Single Family   Single Family
# 2             176680     265000       0.6667  Single Family   Single Family
# 3             146000     243000       0.6008  Single Family   Single Family
# 4             203070     138750       1.4636            NaN             NaN
# ...              ...        ...          ...            ...             ...
# 811355         67290      83500  0.805868263              R             NaN
# 811356        129030     260000  0.496269231              R             NaN
# 811357        110600     190000  0.582105263              R             NaN
# 811358        122000     260900  0.467612112              R             NaN
# 811359         23730      63900  0.371361502              R             NaN
#
#                                           geo_coordinates  \
# 0       {'type': 'Point', 'coordinates': [-71.83583, 4...
# 1       {'type': 'Point', 'coordinates': [-72.787551, ...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 811355  {'type': 'Point', 'coordinates': [-72.639454, ...
# 811356                                                NaN
# 811357  {'type': 'Point', 'coordinates': [-73.184295, ...
# 811358  {'type': 'Point', 'coordinates': [-72.09434, 4...
# 811359  {'type': 'Point', 'coordinates': [-72.701826, ...
#
#        :@computed_region_dam5_q64j :@computed_region_nhmp_cq6b  \
# 0                               39                          71
# 1                             1044                         199
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 811355                        1041                         119
# 811356                         NaN                         NaN
# 811357                        1040                          74
# 811358                        1045                          14
# 811359                        1041                         182
#
#        :@computed_region_m4y2_whse :@computed_region_snd5_k6zv  \
# 0                               69                           5
# 1                               80                           7
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 811355                          43                           1
# 811356                         NaN                         NaN
# 811357                          15                           2
# 811358                         104                           8
# 811359                          64                           1
#
#                 nonusecode remarks opm_remarks Datedaterecorded
# 0                      NaN     NaN         NaN       2019-10-01
# 1                      NaN     NaN         NaN       2019-10-01
# 2                      NaN     NaN         NaN       2019-10-01
# 3                      NaN     NaN         NaN       2019-10-01
# 4       08 - Part Interest     NaN         NaN       2019-10-01
# ...                    ...     ...         ...              ...
# 811355                  14     NaN         NaN       2002-10-01
# 811356                 NaN     NaN         NaN       2002-10-01
# 811357                 NaN     NaN         NaN       2002-10-01
# 811358                 NaN     NaN         NaN       2002-10-01
# 811359                 NaN     NaN         NaN       2002-10-01
#
# [101 rows x 19 columns]

# %%
out =  df.groupby(['listyear','town'])['salesratio'].max().reset_index().sort_values(['salesratio'], ascending=[0])

# %%
out
# Out:
#      listyear           town   salesratio
# 442      2004         Goshen        9e-04
# 2234     2017     Bridgeport  999.9341176
# 1184     2009     Ridgefield  992.5543478
# 1322     2010        Norwalk      990.608
# 98       2001      Southbury  99.99574287
# ...       ...            ...          ...
# 377      2003     Washington  0.435791757
# 329      2003     New London       0.3515
# 353      2003       Scotland      0.33824
# 815      2007  ***Unknown***  0.235581519
# 372      2003          Union        0.007
#
# [2644 rows x 3 columns]

# %%
new_df = out.groupby("listyear").head(10).reset_index(drop=True)

# %%
new_df.loc[new_df['listyear'] == '2001']
# Out:
#     listyear        town   salesratio
# 4       2001   Southbury  99.99574287
# 18      2001      Berlin        99.25
# 36      2001    Stafford  96.78571429
# 48      2001  Ridgefield       95.792
# 68      2001  Washington       93.335
# 80      2001     Norwalk  92.43363363
# 108     2001    Hartford        9.968
# 123     2001      Hamden        9.926
# 149     2001  Bridgeport        9.835
# 166     2001  Manchester  9.764705882

# %%
sa_df =  df.groupby(['listyear','town'])['saleamount'].max().reset_index()

# %%
sa_df.head()
# Out:
#   listyear         town saleamount
# 0     2001      Ansonia      99000
# 1     2001      Ashford      99900
# 2     2001         Avon     975000
# 3     2001  Barkhamsted     962500
# 4     2001       Berlin      96000

# %%
new_df.to_json(orient="records")
# Out:
# '[{"listyear":"2004","town":"Goshen","salesratio":"9e-04"},{"listyear":"2017","town":"Bridgeport","salesratio":"999.9341176"},{"listyear":"2009","town":"Ridgefield","salesratio":"992.5543478"},{"listyear":"2010","town":"Norwalk","salesratio":"990.608"},{"listyear":"2001","town":"Southbury","salesratio":"99.99574287"},{"listyear":"2010","town":"Bridgeport","salesratio":"99.9826087"},{"listyear":"2018","town":"Bridgeport","salesratio":"99.